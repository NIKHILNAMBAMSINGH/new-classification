# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

import os
import cv2
import matplotlib.pyplot as plt
import seaborn as sns

# %%
model5 = Sequential()

# Convolutional layer 1
model5.add(Conv2D(64,(7,7), input_shape=(240, 240, 1), padding='same', activation='relu'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D(pool_size=(2,2)))

#Convolutional layer 2
model5.add(Conv2D(128,(7,7), padding='same', activation='relu'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D(pool_size=(2,2)))

# Convolutional layer 3
model5.add(Conv2D(128,(7,7), padding='same', activation='relu'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D(pool_size=(2,2)))

# Convolutional layer 4
model5.add(Conv2D(256,(7,7), padding='same', activation='relu'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D(pool_size=(2,2)))

 # Convolutional layer 5
model5.add(Conv2D(256,(7,7), padding='same', activation='relu'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D(pool_size=(2,2)))

# Convolutional layer 6
model5.add(Conv2D(512,(7,7), padding='same', activation='relu'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D(pool_size=(2,2)))

model5.add(Flatten())

# Full connect layers

model5.add(Dense(units= 1024, activation='relu'))
model5.add(Dropout(0.25))
model5.add(Dense(units=512, activation='relu'))
model5.add(Dropout(0.25))
model5.add(Dense(units=4, activation='softmax'))

# %%
datagen = ImageDataGenerator(rotation_range=10,
                             height_shift_range=0.2,
                             horizontal_flip=True,
                             validation_split=0.2)

train_data = datagen.flow_from_directory('/content/drive/MyDrive/brain dataset/Training/',
                                         target_size=(240, 240),
                                         batch_size=32,
                                         class_mode='categorical',
                                         subset='training', color_mode='grayscale')

valid_data = datagen.flow_from_directory('/content/drive/MyDrive/brain dataset/Training/',
                                         target_size=(240, 240),
                                         batch_size=32,
                                         class_mode='categorical',
                                         subset='validation', color_mode='grayscale')

#test set
test_datagen = ImageDataGenerator()

test_data = datagen.flow_from_directory('/content/drive/MyDrive/brain dataset/Testing/',
                                         target_size=(240, 240),
                                        class_mode='categorical',shuffle=False, color_mode='grayscale')
# Out:
# Found 4571 images belonging to 4 classes.
# Found 1141 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %%
model5.compile(optimizer=Adam(lr=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

#define checkpoint
checkpoint = ModelCheckpoint('model.h5', 
                             monitor='val_accuracy',
                             save_best_only=True,
                             mode='auto',
                             verbose=1)

#early stopping
earlystop = EarlyStopping(monitor='val_accuracy',
                          patience=5,
                          mode='auto',
                          verbose=1)

#reduce learning rate
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', 
                              factor = 0.3, 
                              patience = 2, 
                              min_delta = 0.001,
                              mode='auto',
                              verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
history = model5.fit(train_data,
                    epochs = 100,
                    validation_data=valid_data,
                    verbose=1,
                    callbacks=[checkpoint, earlystop, reduce_lr])
# Out:
# Epoch 1/100
# 143/143 [==============================] - ETA: 0s - loss: 0.3243 - accuracy: 0.8919
# Epoch 1: val_accuracy improved from -inf to 0.80982, saving model to model.h5
# 143/143 [==============================] - 942s 7s/step - loss: 0.3243 - accuracy: 0.8919 - val_loss: 0.6314 - val_accuracy: 0.8098 - lr: 1.0000e-04
# Epoch 2/100
# 143/143 [==============================] - ETA: 0s - loss: 0.2192 - accuracy: 0.9245
# Epoch 2: val_accuracy improved from 0.80982 to 0.81946, saving model to model.h5
# 143/143 [==============================] - 57s 400ms/step - loss: 0.2192 - accuracy: 0.9245 - val_loss: 0.4900 - val_accuracy: 0.8195 - lr: 1.0000e-04
# Epoch 3/100
# 143/143 [==============================] - ETA: 0s - loss: 0.1725 - accuracy: 0.9372
# Epoch 3: val_accuracy did not improve from 0.81946
# 143/143 [==============================] - 56s 390ms/step - loss: 0.1725 - accuracy: 0.9372 - val_loss: 1.5444 - val_accuracy: 0.6450 - lr: 1.0000e-04
# Epoch 4/100
# 143/143 [==============================] - ETA: 0s - loss: 0.1405 - accuracy: 0.9499
# Epoch 4: val_accuracy improved from 0.81946 to 0.87204, saving model to model.h5
# 143/143 [==============================] - 56s 394ms/step - loss: 0.1405 - accuracy: 0.9499 - val_loss: 0.5082 - val_accuracy: 0.8720 - lr: 1.0000e-04
# Epoch 5/100
# 143/143 [==============================] - ETA: 0s - loss: 0.1131 - accuracy: 0.9608
# Epoch 5: val_accuracy did not improve from 0.87204
# 143/143 [==============================] - 56s 392ms/step - loss: 0.1131 - accuracy: 0.9608 - val_loss: 0.5011 - val_accuracy: 0.8720 - lr: 1.0000e-04
# Epoch 6/100
# 143/143 [==============================] - ETA: 0s - loss: 0.1078 - accuracy: 0.9582
# Epoch 6: val_accuracy did not improve from 0.87204
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 143/143 [==============================] - 56s 391ms/step - loss: 0.1078 - accuracy: 0.9582 - val_loss: 1.1683 - val_accuracy: 0.7677 - lr: 1.0000e-04
# Epoch 7/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0624 - accuracy: 0.9794
# Epoch 7: val_accuracy improved from 0.87204 to 0.93252, saving model to model.h5
# 143/143 [==============================] - 56s 393ms/step - loss: 0.0624 - accuracy: 0.9794 - val_loss: 0.2330 - val_accuracy: 0.9325 - lr: 3.0000e-05
# Epoch 8/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9895
# Epoch 8: val_accuracy improved from 0.93252 to 0.95180, saving model to model.h5
# 143/143 [==============================] - 57s 394ms/step - loss: 0.0346 - accuracy: 0.9895 - val_loss: 0.1872 - val_accuracy: 0.9518 - lr: 3.0000e-05
# Epoch 9/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9897
# Epoch 9: val_accuracy did not improve from 0.95180
# 143/143 [==============================] - 56s 391ms/step - loss: 0.0273 - accuracy: 0.9897 - val_loss: 0.2955 - val_accuracy: 0.9281 - lr: 3.0000e-05
# Epoch 10/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9886
# Epoch 10: val_accuracy did not improve from 0.95180
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 143/143 [==============================] - 56s 390ms/step - loss: 0.0298 - accuracy: 0.9886 - val_loss: 0.3484 - val_accuracy: 0.9159 - lr: 3.0000e-05
# Epoch 11/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9945
# Epoch 11: val_accuracy did not improve from 0.95180
# 143/143 [==============================] - 56s 390ms/step - loss: 0.0186 - accuracy: 0.9945 - val_loss: 0.1930 - val_accuracy: 0.9474 - lr: 9.0000e-06
# Epoch 12/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9950
# Epoch 12: val_accuracy did not improve from 0.95180
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 143/143 [==============================] - 56s 390ms/step - loss: 0.0153 - accuracy: 0.9950 - val_loss: 0.2342 - val_accuracy: 0.9518 - lr: 9.0000e-06
# Epoch 13/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9945
# Epoch 13: val_accuracy improved from 0.95180 to 0.95793, saving model to model.h5
# 143/143 [==============================] - 56s 393ms/step - loss: 0.0146 - accuracy: 0.9945 - val_loss: 0.2032 - val_accuracy: 0.9579 - lr: 2.7000e-06
# Epoch 14/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9976
# Epoch 14: val_accuracy did not improve from 0.95793
# 143/143 [==============================] - 56s 390ms/step - loss: 0.0082 - accuracy: 0.9976 - val_loss: 0.2095 - val_accuracy: 0.9579 - lr: 2.7000e-06
# Epoch 15/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9963
# Epoch 15: val_accuracy did not improve from 0.95793
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 8.099999604382901e-07.
# 143/143 [==============================] - 56s 389ms/step - loss: 0.0139 - accuracy: 0.9963 - val_loss: 0.2091 - val_accuracy: 0.9579 - lr: 2.7000e-06
# Epoch 16/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9950
# Epoch 16: val_accuracy improved from 0.95793 to 0.95968, saving model to model.h5
# 143/143 [==============================] - 56s 394ms/step - loss: 0.0130 - accuracy: 0.9950 - val_loss: 0.1997 - val_accuracy: 0.9597 - lr: 8.1000e-07
# Epoch 17/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9963
# Epoch 17: val_accuracy improved from 0.95968 to 0.96144, saving model to model.h5
# 143/143 [==============================] - 57s 394ms/step - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.1824 - val_accuracy: 0.9614 - lr: 8.1000e-07
# Epoch 18/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9978
# Epoch 18: val_accuracy did not improve from 0.96144
# 143/143 [==============================] - 56s 391ms/step - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.1928 - val_accuracy: 0.9562 - lr: 8.1000e-07
# Epoch 19/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9980
# Epoch 19: val_accuracy did not improve from 0.96144
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.4299998813148704e-07.
# 143/143 [==============================] - 56s 390ms/step - loss: 0.0088 - accuracy: 0.9980 - val_loss: 0.2098 - val_accuracy: 0.9509 - lr: 8.1000e-07
# Epoch 20/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9978
# Epoch 20: val_accuracy did not improve from 0.96144
# 143/143 [==============================] - 56s 390ms/step - loss: 0.0078 - accuracy: 0.9978 - val_loss: 0.1896 - val_accuracy: 0.9606 - lr: 2.4300e-07
# Epoch 21/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9954
# Epoch 21: val_accuracy did not improve from 0.96144
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 7.289999643944612e-08.
# 143/143 [==============================] - 56s 391ms/step - loss: 0.0114 - accuracy: 0.9954 - val_loss: 0.2086 - val_accuracy: 0.9571 - lr: 2.4300e-07
# Epoch 22/100
# 143/143 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9965
# Epoch 22: val_accuracy did not improve from 0.96144
# 143/143 [==============================] - 56s 391ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.2185 - val_accuracy: 0.9544 - lr: 7.2900e-08
# Epoch 22: early stopping

# %%
fig , ax = plt.subplots(1,2)
fig.set_size_inches(20, 8)

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

epochs = range(1, len(train_acc) + 1)

ax[0].plot(epochs , train_acc , 'g-o' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'y-o' , label = 'Validation Accuracy')
ax[0].set_title('Model Training & Validation Accuracy')
ax[0].legend(loc = 'lower right')
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'y-o' , label = 'Validation Loss')
ax[1].set_title('Model Training & Validation & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")

plt.show()

# %%
print('Train accuracy & loss:', model5.evaluate(train_data))
print('\n')
print('Test accuracy & loss:', model5.evaluate(test_data))
# Out:
# 143/143 [==============================] - 37s 257ms/step - loss: 0.0052 - accuracy: 0.9985
# Train accuracy & loss: [0.005154135636985302, 0.9984685778617859]
#
#
# 41/41 [==============================] - 263s 7s/step - loss: 0.0903 - accuracy: 0.9771
# Test accuracy & loss: [0.09033457189798355, 0.9771167039871216]

# %%
import matplotlib.pyplot as plt
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm

# %%
y_test = test_data.classes

#make prediction
yhat_test = np.argmax(model5.predict(test_data), axis=1)

# %%
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize = False,
                          title = 'Confusion matrix',
                          cmap = plt.cm.Blues):
    
    plt.figure(figsize = (6,6))
    plt.imshow(cm, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    plt.colorbar()
    plt.grid(False)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]

    thresh = cm.max() / 2.
    cm = np.round(cm,2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 fontsize = 12,
                 horizontalalignment = "center",
                 color = "white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
      
#get confusion matrix
cm = confusion_matrix(y_test, yhat_test)
print(cm)
# Out:
# [[295   3   0   2]
#  [  0 287  10   9]
#  [  5   0 400   0]
#  [  0   1   0 299]]

# %%
classes = os.listdir('/content/drive/MyDrive/brain dataset/Training/')

# %%
cm = confusion_matrix(y_test, yhat_test)
print(cm)

#plot
plot_confusion_matrix(cm, classes, normalize=False)
# Out:
# [[295   3   0   2]
#  [  0 287  10   9]
#  [  5   0 400   0]
#  [  0   1   0 299]]

# %%
print(classification_report(y_test, yhat_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       300
#            1       0.99      0.94      0.96       306
#            2       0.98      0.99      0.98       405
#            3       0.96      1.00      0.98       300
#
#     accuracy                           0.98      1311
#    macro avg       0.98      0.98      0.98      1311
# weighted avg       0.98      0.98      0.98      1311

# %%
import matplotlib.pyplot as plt
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']
X_train = []
y_train = []
image_size = 224
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/new one','Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)
        
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/new one','Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 826/826 [00:06<00:00, 123.96it/s]
# 100%|██████████| 395/395 [00:02<00:00, 143.66it/s]
# 100%|██████████| 822/822 [00:06<00:00, 122.72it/s]
# 100%|██████████| 827/827 [00:07<00:00, 117.37it/s]
# 100%|██████████| 100/100 [00:00<00:00, 134.17it/s]
# 100%|██████████| 105/105 [00:00<00:00, 181.24it/s]
# 100%|██████████| 115/115 [00:00<00:00, 148.47it/s]
# 100%|██████████| 74/74 [00:00<00:00, 85.45it/s]

# %%
colors_dark = ["#1F1F1F", "#313131", '#636363', '#AEAEAE', '#DADADA']
colors_red = ["#331313", "#582626", '#9E1717', '#D35151', '#E9B4B4']
colors_green = ['#01411C','#4B6F44','#4F7942','#74C365','#D0F0C0']

sns.palplot(colors_dark)
sns.palplot(colors_green)
sns.palplot(colors_red)

# %%
k=0
fig, ax = plt.subplots(1,4,figsize=(20,20))
fig.text(s='Sample Image From Each Label',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=0.62,x=0.4,alpha=0.8)
for i in labels:
    j=0
    while True :
        if y_train[j]==i:
            ax[k].imshow(X_train[j])
            ax[k].set_title(y_train[j])
            ax[k].axis('off')
            k+=1
            break
        j+=1

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

# %%
X_train.shape
# Out:
# (3264, 224, 224, 3)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.2,random_state=101)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
effnet = EfficientNetB1(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))

# %%
model = effnet.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=effnet.input, outputs = model)

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("effnet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.1, epochs =20, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/20
# 74/74 [==============================] - ETA: 0s - loss: 0.4408 - accuracy: 0.8378
# Epoch 1: val_accuracy improved from -inf to 0.80916, saving model to effnet.h5
# 74/74 [==============================] - 87s 907ms/step - loss: 0.4408 - accuracy: 0.8378 - val_loss: 0.5091 - val_accuracy: 0.8092 - lr: 0.0010
# Epoch 2/20
# 74/74 [==============================] - ETA: 0s - loss: 0.1768 - accuracy: 0.9400
# Epoch 2: val_accuracy improved from 0.80916 to 0.91603, saving model to effnet.h5
# 74/74 [==============================] - 63s 851ms/step - loss: 0.1768 - accuracy: 0.9400 - val_loss: 0.2210 - val_accuracy: 0.9160 - lr: 0.0010
# Epoch 3/20
# 74/74 [==============================] - ETA: 0s - loss: 0.1152 - accuracy: 0.9672
# Epoch 3: val_accuracy did not improve from 0.91603
# 74/74 [==============================] - 62s 832ms/step - loss: 0.1152 - accuracy: 0.9672 - val_loss: 0.3526 - val_accuracy: 0.8893 - lr: 0.0010
# Epoch 4/20
# 74/74 [==============================] - ETA: 0s - loss: 0.1270 - accuracy: 0.9600
# Epoch 4: val_accuracy did not improve from 0.91603
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 74/74 [==============================] - 62s 832ms/step - loss: 0.1270 - accuracy: 0.9600 - val_loss: 0.3688 - val_accuracy: 0.8855 - lr: 0.0010
# Epoch 5/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9847
# Epoch 5: val_accuracy improved from 0.91603 to 0.95420, saving model to effnet.h5
# 74/74 [==============================] - 62s 832ms/step - loss: 0.0528 - accuracy: 0.9847 - val_loss: 0.1354 - val_accuracy: 0.9542 - lr: 3.0000e-04
# Epoch 6/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9949
# Epoch 6: val_accuracy improved from 0.95420 to 0.96183, saving model to effnet.h5
# 74/74 [==============================] - 62s 834ms/step - loss: 0.0207 - accuracy: 0.9949 - val_loss: 0.1437 - val_accuracy: 0.9618 - lr: 3.0000e-04
# Epoch 7/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9962
# Epoch 7: val_accuracy improved from 0.96183 to 0.97328, saving model to effnet.h5
# 74/74 [==============================] - 63s 853ms/step - loss: 0.0136 - accuracy: 0.9962 - val_loss: 0.1146 - val_accuracy: 0.9733 - lr: 3.0000e-04
# Epoch 8/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9962
# Epoch 8: val_accuracy improved from 0.97328 to 0.98092, saving model to effnet.h5
# 74/74 [==============================] - 62s 834ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.1066 - val_accuracy: 0.9809 - lr: 3.0000e-04
# Epoch 9/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9962
# Epoch 9: val_accuracy did not improve from 0.98092
# 74/74 [==============================] - 61s 829ms/step - loss: 0.0112 - accuracy: 0.9962 - val_loss: 0.1104 - val_accuracy: 0.9809 - lr: 3.0000e-04
# Epoch 10/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9991
# Epoch 10: val_accuracy did not improve from 0.98092
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 74/74 [==============================] - 61s 830ms/step - loss: 0.0071 - accuracy: 0.9991 - val_loss: 0.1170 - val_accuracy: 0.9809 - lr: 3.0000e-04
# Epoch 11/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9979
# Epoch 11: val_accuracy improved from 0.98092 to 0.98473, saving model to effnet.h5
# 74/74 [==============================] - 62s 835ms/step - loss: 0.0081 - accuracy: 0.9979 - val_loss: 0.0957 - val_accuracy: 0.9847 - lr: 9.0000e-05
# Epoch 12/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9996
# Epoch 12: val_accuracy did not improve from 0.98473
# 74/74 [==============================] - 60s 816ms/step - loss: 0.0030 - accuracy: 0.9996 - val_loss: 0.0909 - val_accuracy: 0.9847 - lr: 9.0000e-05
# Epoch 13/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9991
# Epoch 13: val_accuracy did not improve from 0.98473
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 74/74 [==============================] - 60s 815ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.0939 - val_accuracy: 0.9809 - lr: 9.0000e-05
# Epoch 14/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9983
# Epoch 14: val_accuracy did not improve from 0.98473
# 74/74 [==============================] - 61s 831ms/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 0.0940 - val_accuracy: 0.9809 - lr: 2.7000e-05
# Epoch 15/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9996
# Epoch 15: val_accuracy did not improve from 0.98473
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 74/74 [==============================] - 61s 829ms/step - loss: 0.0025 - accuracy: 0.9996 - val_loss: 0.0942 - val_accuracy: 0.9809 - lr: 2.7000e-05
# Epoch 16/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9996
# Epoch 16: val_accuracy did not improve from 0.98473
# 74/74 [==============================] - 61s 830ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.0947 - val_accuracy: 0.9809 - lr: 8.1000e-06
# Epoch 17/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 0.98473
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 74/74 [==============================] - 61s 831ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0956 - val_accuracy: 0.9809 - lr: 8.1000e-06
# Epoch 18/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9996
# Epoch 18: val_accuracy did not improve from 0.98473
# 74/74 [==============================] - 60s 815ms/step - loss: 0.0034 - accuracy: 0.9996 - val_loss: 0.0951 - val_accuracy: 0.9809 - lr: 2.4300e-06
# Epoch 19/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9991
# Epoch 19: val_accuracy did not improve from 0.98473
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# 74/74 [==============================] - 60s 818ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.0947 - val_accuracy: 0.9809 - lr: 2.4300e-06
# Epoch 20/20
# 74/74 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9987
# Epoch 20: val_accuracy did not improve from 0.98473
# 74/74 [==============================] - 61s 831ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0947 - val_accuracy: 0.9809 - lr: 7.2900e-07

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97       168
#            1       0.98      0.98      0.98       108
#            2       0.96      0.99      0.98       201
#            3       0.99      0.99      0.99       176
#
#     accuracy                           0.98       653
#    macro avg       0.98      0.98      0.98       653
# weighted avg       0.98      0.98      0.98       653

# %%
train_pred = model.predict(X_train)
train_pred = np.argmax(train_pred, axis=1)
Y_train_ = np.argmax(y_train, axis=1)
print("Accuracy on training set: {:.2f}%".format(np.sum(train_pred==Y_train_)/len(Y_train_)*100))
# Out:
# Accuracy on training set: 99.81%

# %%
test_pred = model.predict(X_test)
test_pred = np.argmax(test_pred, axis=1)
Y_test_ = np.argmax(y_test, axis=1)
print("Accuracy on testing set: {:.2f}%".format(np.sum(test_pred==Y_test_)/len(Y_test_)*100))
# Out:
# Accuracy on testing set: 98.01%
